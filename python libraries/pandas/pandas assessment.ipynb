# %%
import pandas as pd

# Create sample data with missing values and duplicates
data = {
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Alice', 'Eve', 'Frank', 'Grace', 'Bob', None],
    'age': [25, None, 30, 35, 25, 28, None, 40, 30, 32],
    'salary': [50000, 60000, None, 80000, 50000, 55000, 70000, None, 60000, 65000],
    'department': ['HR', 'IT', 'IT', 'Finance', 'HR', 'Marketing', 'Finance', 'HR', 'IT', 'Marketing'],
    'years_experience': [2, 5, 7, 10, 2, 4, 8, 15, 5, None]
}

# Create DataFrame and save to CSV


# Confirm the file was created


import pandas as pd

# Task 1: Read the CSV file into a DataFrame
# - Use pd.read_csv() to load 'employees.csv'
# - Ensure the file is in your working directory or provide the correct path


# print(df)  # Uncomment to verify the DataFrame

# Task 2: Display the first 5 rows using head()
# - Use head() to inspect the first 5 rows (default)
# - Helps understand column names, data types, and spot missing values

# Task 3: Display the last 5 rows using tail()
# - Use tail() to show the last 5 rows (default)
# - Useful for checking the end of the dataset

# Task 4: Get DataFrame information using info()
# - Use info() to display column names, non-null counts, and data types
# - Helps identify missing values and data types

# Task 5: Generate summary statistics using describe()
# - Use describe() for numerical columns (count, mean, std, min, max, quartiles)
# - Excludes non-numerical columns like 'name' and 'department'

# Task 6: Fill missing values using fillna()
# - For 'age', fill with the mean age
# - For 'salary', fill with the median salary
# - For 'name', fill with 'Unknown'
# - Use fillna() and reassign or use inplace=True



# Task 7: Drop rows with missing values in 'years_experience' using dropna()
# - Use dropna() with subset=['years_experience'] to drop rows where 'years_experience' is NaN
# - Reassign the DataFrame or use inplace=True




# Task 8: Find duplicates using duplicated()
# - Use duplicated() to identify duplicate rows (based on all columns)
# - Also check duplicates based on 'name' and 'age' using subset



# Task 9: Remove duplicates using drop_duplicates()
# - Remove duplicates based on 'name' and 'age' (keep the first occurrence)
# - Use drop_duplicates() with subset=['name', 'age'] and inplace=True



# Task 10: Calculate summary statistics again after cleaning
# - Use describe() to see updated statistics for numerical columns
# - Compare with Task 5 to see the effect of filling/dropping missing values and duplicates
